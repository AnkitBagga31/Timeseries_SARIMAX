# %%
import pandas as pd

# %%
import numpy as np

# %%
df = pd.read_csv("/Users/admin/Desktop/sales.csv", parse_dates = True, index_col = "date")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 168 entries, 1962-01-01 to 1975-12-01
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   sales   168 non-null    float64
# dtypes: float64(1)
# memory usage: 2.6 KB

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(df["sales"])
plt.show()

# %%
from statsmodels.tsa.stattools import adfuller

# %%
adfuller(df)
# Out:
# (-1.3038115874221246,
#  0.627426708603034,
#  13,
#  154,
#  {'1%': -3.473542528196209,
#   '5%': -2.880497674144038,
#   '10%': -2.576878053634677},
#  1115.1730447395112)

# %%
#p value is more than 0.05 then we reject the null hypothesis that the data is non stationary

# %%
df_diff = df.diff().dropna()

# %%
adfuller(df_diff)
# Out:
# (-3.0549955586531095,
#  0.0300680040017824,
#  14,
#  152,
#  {'1%': -3.474120870218417,
#   '5%': -2.880749791423677,
#   '10%': -2.5770126333102494},
#  1107.6745114331075)

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

# %%
plot_acf(df_diff, lags = 100, zero = False)

# %%
pip install pmdarima
# Out:
# Requirement already satisfied: pmdarima in /Users/admin/opt/anaconda3/lib/python3.8/site-packages (1.8.2)
# Requirement already satisfied: pandas>=0.19 in /Users/admin/opt/anaconda3/lib/python3.8/site-packages (from pmdarima) (1.2.4)
# Requirement already satisfied: statsmodels!=0.12.0,>=0.11 in /Users/admin/opt/anaconda3/lib/python3.8/site-packages (from pmdarima) (0.12.2)
# Requirement already satisfied: Cython!=0.29.18,>=0.29 in /Users/admin/opt/anaconda3/lib/python3.8/site-packages (from pmdarima) (0.29.23)
# Requirement already satisfied: scikit-learn>=0.22 in /Users/admin/opt/anaconda3/lib/python3.8/site-packages (from pmdarima) (0.24.1)
# Requirement already satisfied: numpy~=1.19.0 in /Users/admin/opt/anaconda3/lib/python3.8/site-packages (from pmdarima) (1.19.5)
# Requirement already satisfied: scipy>=1.3.2 in /Users/admin/opt/anaconda3/lib/python3.8/site-packages (from pmdarima) (1.6.2)
# Requirement already satisfied: setuptools!=50.0.0,>=38.6.0 in /Users/admin/opt/anaconda3/lib/python3.8/site-packages (from pmdarima) (52.0.0.post20210125)
# Requirement already satisfied: urllib3 in /Users/admin/opt/anaconda3/lib/python3.8/site-packages (from pmdarima) (1.26.4)
# Requirement already satisfied: joblib>=0.11 in /Users/admin/opt/anaconda3/lib/python3.8/site-packages (from pmdarima) (1.0.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /Users/admin/opt/anaconda3/lib/python3.8/site-packages (from pandas>=0.19->pmdarima) (2.8.1)
# Requirement already satisfied: pytz>=2017.3 in /Users/admin/opt/anaconda3/lib/python3.8/site-packages (from pandas>=0.19->pmdarima) (2021.1)
# Requirement already satisfied: six>=1.5 in /Users/admin/opt/anaconda3/lib/python3.8/site-packages (from python-dateutil>=2.7.3->pandas>=0.19->pmdarima) (1.15.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/admin/opt/anaconda3/lib/python3.8/site-packages (from scikit-learn>=0.22->pmdarima) (2.1.0)
# Requirement already satisfied: patsy>=0.5 in /Users/admin/opt/anaconda3/lib/python3.8/site-packages (from statsmodels!=0.12.0,>=0.11->pmdarima) (0.5.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pmdarima as pm

# %%
results = pm.auto_arima(df, seasonal = True, m = 12, d = 1, D = 1, information_criterion = "bic", trace = True, error_action = "ignore", n_fits = 100, stepwise = True)
# Out:
# Performing stepwise search to minimize bic
#  ARIMA(2,1,2)(1,1,1)[12]             : BIC=1091.526, Time=2.11 sec
#  ARIMA(0,1,0)(0,1,0)[12]             : BIC=1123.012, Time=0.02 sec
#  ARIMA(1,1,0)(1,1,0)[12]             : BIC=1090.714, Time=0.10 sec
#  ARIMA(0,1,1)(0,1,1)[12]             : BIC=1075.427, Time=0.12 sec
#  ARIMA(0,1,1)(0,1,0)[12]             : BIC=1121.082, Time=0.03 sec
#  ARIMA(0,1,1)(1,1,1)[12]             : BIC=1080.203, Time=0.16 sec
#  ARIMA(0,1,1)(0,1,2)[12]             : BIC=1080.150, Time=0.34 sec
#  ARIMA(0,1,1)(1,1,0)[12]             : BIC=1091.253, Time=0.07 sec
#  ARIMA(0,1,1)(1,1,2)[12]             : BIC=inf, Time=1.85 sec
#  ARIMA(0,1,0)(0,1,1)[12]             : BIC=1078.367, Time=0.16 sec
#  ARIMA(1,1,1)(0,1,1)[12]             : BIC=1080.238, Time=0.18 sec
#  ARIMA(0,1,2)(0,1,1)[12]             : BIC=1079.970, Time=0.23 sec
#  ARIMA(1,1,0)(0,1,1)[12]             : BIC=1075.337, Time=0.13 sec
#  ARIMA(1,1,0)(0,1,0)[12]             : BIC=1120.932, Time=0.03 sec
#  ARIMA(1,1,0)(1,1,1)[12]             : BIC=1080.087, Time=0.17 sec
#  ARIMA(1,1,0)(0,1,2)[12]             : BIC=1080.030, Time=0.42 sec
#  ARIMA(1,1,0)(1,1,2)[12]             : BIC=inf, Time=1.03 sec
#  ARIMA(2,1,0)(0,1,1)[12]             : BIC=1080.095, Time=0.12 sec
#  ARIMA(2,1,1)(0,1,1)[12]             : BIC=1081.913, Time=0.50 sec
#  ARIMA(1,1,0)(0,1,1)[12] intercept   : BIC=1080.374, Time=0.15 sec
#
# Best model:  ARIMA(1,1,0)(0,1,1)[12]
# Total fit time: 7.933 seconds

# %%
results. summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                       SARIMAX Results
# ============================================================================================
# Dep. Variable:                                    y   No. Observations:                  168
# Model:             SARIMAX(1, 1, 0)x(0, 1, [1], 12)   Log Likelihood                -530.104
# Date:                              Tue, 29 Jun 2021   AIC                           1066.207
# Time:                                      13:25:39   BIC                           1075.337
# Sample:                                           0   HQIC                          1069.916
#                                               - 168
# Covariance Type:                                opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.2253      0.077     -2.925      0.003      -0.376      -0.074
# ma.S.L12      -0.6190      0.070     -8.825      0.000      -0.757      -0.482
# sigma2        52.6908      4.897     10.759      0.000      43.093      62.289
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.01   Jarque-Bera (JB):                35.11
# Prob(Q):                              0.91   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.82   Skew:                             0.74
# Prob(H) (two-sided):                  0.49   Kurtosis:                         4.80
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
results.plot_diagnostics()

# %%
from pmdarima.model_selection import train_test_split

# %%
train, test = train_test_split(df, test_size =0.3)

# %%
test.shape
# Out:
# (51, 1)

# %%
prediction = pd.DataFrame(results.predict(n_periods = 51), test.index)
prediction.columns = ["predicted_sales"]
test["predicted_sales"] = prediction
# Out:
# <ipython-input-25-62b25f8a551c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test["predicted_sales"] = prediction

# %%
test
# Out:
#             sales  predicted_sales
# date
# 1971-10-01  800.0       865.349740
# 1971-11-01  763.0       818.387707
# 1971-12-01  800.0       925.019489
# 1972-01-01  826.0       938.096591
# 1972-02-01  799.0      1001.238547
# 1972-03-01  890.0       973.830260
# 1972-04-01  900.0       932.477681
# 1972-05-01  961.0       892.889158
# 1972-06-01  935.0       846.994443
# 1972-07-01  894.0       852.166204
# 1972-08-01  855.0       818.130555
# 1972-09-01  809.0       860.408590
# 1972-10-01  810.0       883.596821
# 1972-11-01  766.0       836.445891
# 1972-12-01  805.0       943.120229
# 1973-01-01  821.0       956.187743
# 1973-02-01  773.0      1019.331859
# 1973-03-01  883.0       991.923085
# 1973-04-01  898.0       950.570617
# 1973-05-01  957.0       910.982068
# 1973-06-01  924.0       865.087359
# 1973-07-01  881.0       870.259119
# 1973-08-01  837.0       836.223470
# 1973-09-01  784.0       878.501505
# 1973-10-01  791.0       901.689736
# 1973-11-01  760.0       854.538806
# 1973-12-01  802.0       961.213144
# 1974-01-01  828.0       974.280658
# 1974-02-01  778.0      1037.424774
# 1974-03-01  889.0      1010.016000
# 1974-04-01  902.0       968.663532
# 1974-05-01  969.0       929.074983
# 1974-06-01  947.0       883.180274
# 1974-07-01  908.0       888.352034
# 1974-08-01  867.0       854.316385
# 1974-09-01  815.0       896.594420
# 1974-10-01  812.0       919.782651
# 1974-11-01  773.0       872.631721
# 1974-12-01  813.0       979.306059
# 1975-01-01  834.0       992.373573
# 1975-02-01  782.0      1055.517689
# 1975-03-01  892.0      1028.108915
# 1975-04-01  903.0       986.756447
# 1975-05-01  966.0       947.167898
# 1975-06-01  937.0       901.273189
# 1975-07-01  896.0       906.444949
# 1975-08-01  858.0       872.409300
# 1975-09-01  817.0       914.687335
# 1975-10-01  827.0       937.875566
# 1975-11-01  797.0       890.724636
# 1975-12-01  843.0       997.398974

# %%
plt.figure(figsize = (16,10))
plt.plot(train, label = "Training")
plt.plot(test, label = "Testing")
plt.plot(prediction, label = "Prediction")
plt.legend()

# %%
df.shape
# Out:
# (168, 1)

# %%
from pandas.tseries.offsets import DateOffset
future_dates = [df.index[-1] + DateOffset(months = x) for x in range(0,24)]

# %%
future_dates
# Out:
# [Timestamp('1975-12-01 00:00:00'),
#  Timestamp('1976-01-01 00:00:00'),
#  Timestamp('1976-02-01 00:00:00'),
#  Timestamp('1976-03-01 00:00:00'),
#  Timestamp('1976-04-01 00:00:00'),
#  Timestamp('1976-05-01 00:00:00'),
#  Timestamp('1976-06-01 00:00:00'),
#  Timestamp('1976-07-01 00:00:00'),
#  Timestamp('1976-08-01 00:00:00'),
#  Timestamp('1976-09-01 00:00:00'),
#  Timestamp('1976-10-01 00:00:00'),
#  Timestamp('1976-11-01 00:00:00'),
#  Timestamp('1976-12-01 00:00:00'),
#  Timestamp('1977-01-01 00:00:00'),
#  Timestamp('1977-02-01 00:00:00'),
#  Timestamp('1977-03-01 00:00:00'),
#  Timestamp('1977-04-01 00:00:00'),
#  Timestamp('1977-05-01 00:00:00'),
#  Timestamp('1977-06-01 00:00:00'),
#  Timestamp('1977-07-01 00:00:00'),
#  Timestamp('1977-08-01 00:00:00'),
#  Timestamp('1977-09-01 00:00:00'),
#  Timestamp('1977-10-01 00:00:00'),
#  Timestamp('1977-11-01 00:00:00')]

# %%
future_date_df = pd.DataFrame(index = future_dates[1:],columns = df.columns)

# %%
future_date_df.tail()
# Out:
#            sales
# 1977-07-01   NaN
# 1977-08-01   NaN
# 1977-09-01   NaN
# 1977-10-01   NaN
# 1977-11-01   NaN

# %%
future_date_df.shape
# Out:
# (23, 1)

# %%
future_date_df["forecast"] = results.predict(n_periods = 23,dynamic  = True )

# %%
future_df = pd.concat([df,future_date_df])

# %%
future_df
# Out:
#             sales    forecast
# 1962-01-01  589.0         NaN
# 1962-02-01  561.0         NaN
# 1962-03-01  640.0         NaN
# 1962-04-01  656.0         NaN
# 1962-05-01  727.0         NaN
# ...           ...         ...
# 1977-07-01    NaN  950.570617
# 1977-08-01    NaN  910.982068
# 1977-09-01    NaN  865.087359
# 1977-10-01    NaN  870.259119
# 1977-11-01    NaN  836.223470
#
# [191 rows x 2 columns]

# %%
future_df.plot()
# Out:
# <AxesSubplot:>
